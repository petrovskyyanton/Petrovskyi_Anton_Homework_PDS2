# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import statsmodels.api as sm

# %%
df = pd.read_csv('Data_to_Transform.csv')
df
# Out:
#       Moderate Positive Skew  Highly Positive Skew  Moderate Negative Skew  \
# 0                   0.899990              2.895074               11.180748
# 1                   1.113554              2.962385               10.842938
# 2                   1.156830              2.966378               10.817934
# 3                   1.264131              3.000324               10.764570
# 4                   1.323914              3.012109               10.753117
# ...                      ...                   ...                     ...
# 9995               14.749050             16.289513               -2.980821
# 9996               14.854474             16.396252               -3.147526
# 9997               15.262103             17.102991               -3.517256
# 9998               15.269983             17.628467               -4.689833
# 9999               16.204517             18.052331               -6.335679
#
#       Highly Negative Skew
# 0                 9.027485
# ...

# %% [markdown]
# ### Moderate Positive Skew

# %%
sns.histplot(df['Moderate Positive Skew'])
fig = plt.figure()

# %%
df_log = np.log(df['Moderate Positive Skew'])

# %%
sns.histplot(df_log)
fig = plt.figure()

# %%
df_log10 = np.log10(df['Moderate Positive Skew'])

# %%
sns.histplot(df_log10)
fig = plt.figure()

# %%
from sklearn.preprocessing import PowerTransformer

# %%
data = df['Moderate Positive Skew'].values.reshape(-1, 1)

# %%
pt = PowerTransformer(method='box-cox')
df_boxcox = pt.fit_transform(data)

# %%
sns.histplot(df_boxcox)
fig = plt.figure()

# %%
df_1 = np.int64(df['Moderate Positive Skew'])
fig = sm.qqplot(df_1, line='45')
plt.show()

# %%
fig = sm.qqplot(df_log, line='45')
plt.show()

# %%
fig = sm.qqplot(df_log10, line='45')
plt.show()

# %%
fig = sm.qqplot(df_boxcox, line='45')
plt.show()

# %% [markdown]
# ### Highly Positive Skew

# %%
sns.histplot(df['Highly Positive Skew'])
fig = plt.figure()

# %%
data_1 = df['Highly Positive Skew'].values.reshape(-1, 1)

# %%
pt = PowerTransformer(method='box-cox')
df_boxcox_1 = pt.fit_transform(data_1)

# %%
sns.histplot(df_boxcox_1)
fig = plt.figure()

# %%
fig = sm.qqplot(df_boxcox_1, line='45')
plt.show()

# %% [markdown]
# ### Moderate Negative Skew

# %%
sns.histplot(df['Moderate Negative Skew'])
fig = plt.figure()

# %%
data_2 = df['Moderate Negative Skew'].values.reshape(-1, 1)

# %%
pt = PowerTransformer(method='yeo-johnson')
df_boxcox_2 = pt.fit_transform(data_2)
# yeo-johnson

# %%
sns.histplot(df_boxcox_2)
fig = plt.figure()

# %%
fig = sm.qqplot(df_boxcox_2, line='45')
plt.show()

# %% [markdown]
# ### Highly Negative Skew

# %%
sns.histplot(df['Highly Negative Skew'])
fig = plt.figure()

# %%
data_3 = df['Highly Negative Skew'].values.reshape(-1, 1)

# %%
pt = PowerTransformer(method='yeo-johnson')
df_boxcox_3 = pt.fit_transform(data_3)
# yeo-johnson

# %%
sns.histplot(df_boxcox_3)
fig = plt.figure()

# %%
fig = sm.qqplot(df_boxcox_3, line='45')
plt.show()
