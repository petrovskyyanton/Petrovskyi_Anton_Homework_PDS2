# %% [markdown]
# ### Метод детекції облич Віоли-Джонса

# %%
import cv2

import matplotlib.pyplot as plt

import numpy as np

# %%
face_cascade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

# %%
img = cv2.imread("titanic.jpg")
plt.imshow(img)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
faces = face_cascade.detectMultiScale(gray, 1.3, 7)

# %%
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 5)

# %%
plt.imshow(img)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
img = cv2.imread("titanic.jpg")
rotated_image = cv2.rotate(img, cv2.ROTATE_90_CLOCKWISE)
plt.imshow(rotated_image)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
gray = cv2.cvtColor(rotated_image, cv2.COLOR_BGR2GRAY)

# %%
faces = face_cascade.detectMultiScale(gray, 1.3, 5)

# %%
for (x, y, w, h) in faces:
    cv2.rectangle(rotated_image, (x, y), (x+w, y+h), (255, 0, 0), 5)

# %%
plt.imshow(rotated_image)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Метод детекції облич HOG в Dlib

# %%
import dlib
from imutils import face_utils

# %%
img = cv2.imread("titanic.jpg")
plt.imshow(img)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
gray = cv2.imread('titanic.jpg', 0)
im = np.float32(gray) / 255.0
# Computing gradients
gx = cv2.Sobel(im, cv2.CV_32F, 1, 0, ksize=1)
gy = cv2.Sobel(im, cv2.CV_32F, 0, 1, ksize=1)
mag, angle = cv2.cartToPolar(gx, gy, angleInDegrees=True)

# %%
plt.imshow(mag)
plt.show()

# %%
face_detect = dlib.get_frontal_face_detector()
rects = face_detect(gray, 1)

for (i, rect) in enumerate(rects):
    (x, y, w, h) = face_utils.rect_to_bb(rect)
    cv2.rectangle(gray, (x, y), (x + w, y + h), (255, 255, 255), 3)
    
plt.figure(figsize=(10,6))
plt.imshow(gray, cmap='gray')
plt.show()

# %%
img = cv2.imread("titanic.jpg")
img = cv2.rotate(img, cv2.ROTATE_90_CLOCKWISE)
plt.imshow(img)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
im = np.float32(img) / 255.0
# Computing gradients
gx = cv2.Sobel(im, cv2.CV_32F, 1, 0, ksize=1)
gy = cv2.Sobel(im, cv2.CV_32F, 0, 1, ksize=1)
mag, angle = cv2.cartToPolar(gx, gy, angleInDegrees=True)

# %%
face_detect = dlib.get_frontal_face_detector()
rects = face_detect(gray, 1)

for (i, rect) in enumerate(rects):
    (x, y, w, h) = face_utils.rect_to_bb(rect)
    cv2.rectangle(gray, (x, y), (x + w, y + h), (255, 255, 255), 3)
    
plt.figure(figsize=(10,6))
plt.imshow(gray, cmap='gray')
plt.show()

# %% [markdown]
# ### Висновок
# Метод детекції облич HOG в Dlib виявився дещо кращим за метод Віоли-Джонса (в першому випадку рамка розпізнавання актора трохи менше).
