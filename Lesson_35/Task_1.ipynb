# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn
import pandas as pd

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import scale

from pylab import rcParams
rcParams['figure.figsize'] = 10,8

# %%
stud = pd.read_csv('student_scores.csv')
stud.head()
stud.shape
# Out:
# (25, 2)

# %%
plt.plot(stud['Scores'], stud['Hours'], 'ro')
plt.xlabel('Hours')
plt.ylabel('Scores')
plt.show()

# %%
stud.describe()
# Out:
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %%
X = stud[['Hours']].values
y = stud[['Scores']].values

# %%
LinReg = LinearRegression()
LinReg.fit(X,y)
print(LinReg.intercept_, LinReg.coef_)
# Out:
# [2.48367341] [[9.77580339]]

# %%
X_new = np.random.randint(1,100,(100, 1))
X_new[1:10]
# Out:
# array([[82],
#        [60],
#        [64],
#        [32],
#        [77],
#        [89],
#        [27],
#        [37],
#        [47]])

# %%
y_new = LinReg.predict(X_new)
y_new[1:10]
# Out:
# array([[804.09955145],
#        [589.03187685],
#        [628.13509042],
#        [315.30938191],
#        [755.2205345 ],
#        [872.53017519],
#        [266.43036496],
#        [364.18839886],
#        [461.94643277]])

# %%
plt.scatter(X, y, color = 'green')
plt.plot(X_new, y_new, color = 'black')
plt.xlim(1, 10)
plt.ylim(1, 100)
plt.text(6, 55, '$f(x)=2,48+9,78x$', fontsize = 20)
plt.xlabel('Hours')
plt.ylabel('Score')
plt.show()

# %%
print(LinReg.score(X, y))
# Out:
# 0.9529481969048356

# %% [markdown]
# ## Висновок

# %% [markdown]
# Дана модель має високу прогностичну здатність (згідно доволі високому коефіцієнту детермінації), тому може використовуватися для передбачення даних.
