# %%
import pandas as pd
import numpy as np
from pandas.plotting import scatter_matrix
from adtk.data import validate_series
from adtk.visualization import plot
from adtk.detector import ThresholdAD
from adtk.detector import OutlierDetector

from sklearn.neighbors import LocalOutlierFactor
from scipy.stats import variation
import seaborn as sns
import matplotlib.pyplot as plt

import statsmodels.api as sm
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.api import ExponentialSmoothing
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_pacf,plot_acf
from statsmodels.stats.outliers_influence import variance_inflation_factor
from itertools import compress, product

from pmdarima import auto_arima

import warnings
warnings.filterwarnings("ignore")

# %%
def sesonal(data, s):
    plt.figure(figsize=(19,8), dpi= 80)
    for i, y in enumerate(data.index.year.unique()):
        plt.plot(list(range(1,len(data[data.index.year==y])+1)), data[data.index.year==y][data.columns[0]].values, label=y)
    plt.title("Сезонність по періодам")
    plt.legend(loc="best")
    plt.show()

# %%
def metrics(real, forecast):
    
    if type(real)==pd.core.frame.DataFrame:
        real=real[real.columns[0]].values
    
    print("Тест на стаціонарність:")
    dftest = adfuller(real-forecast, autolag='AIC')
    print("\tT-статистика = {:.3f}".format(dftest[0]))
    print("\tP-значення = {:.3f}".format(dftest[1]))
    print("Критичне значення :")
    for k, v in dftest[4].items():
        print("\t{}: {} - Дані {} стационарні з ймовірністю {}% відсотків".format(k, v, "не" if v<dftest[0] else "", 100-int(k[:-1])))
    
    forecast=np.array(forecast)
    print('MAD:', round(abs(real-forecast).mean(),4))
    print('MSE:', round(((real-forecast)**2).mean(),4))
    print('MAPE:', round((abs(real-forecast)/real).mean(),4))
    print('MPE:', round(((real-forecast)/real).mean(),4))
    print('Стандартна похибка:', round(((real-forecast)**2).mean()**0.5,4))

# %%
df=pd.read_csv("cardox.csv", index_col='date')
df.head()
# Out:
#              value
# date
# 1958-03-01  315.71
# 1958-04-01  317.45
# 1958-05-01  317.50
# 1958-06-01  317.10
# 1958-07-01  315.86

# %%
df.shape
# Out:
# (729, 1)

# %%
df.index = pd.to_datetime(df.index)

# %%
plot(df, ts_linewidth=3)
# Out:
# [<AxesSubplot: >]

# %%
df.describe()
# Out:
#             value
# count  729.000000
# mean   353.787229
# std     27.547500
# min    312.660000
# 25%    328.570000
# 50%    351.410000
# 75%    375.990000
# max    411.240000

# %%
outlier_detector = OutlierDetector(LocalOutlierFactor())
anomalies = outlier_detector.fit_detect(df)
# contamination=0.01
plot(df, anomaly=anomalies, ts_linewidth=2, anomaly_color='red', anomaly_alpha=0.3, curve_group='all');

# %%
anomalies[anomalies]
# Out:
# date
# 1958-09-01    True
# 1958-10-01    True
# 1958-11-01    True
# 1959-10-01    True
# dtype: bool

# %%
sesonal(df,12)

# %%
result_M = seasonal_decompose(df.value, model='multiplicative', extrapolate_trend=12)

plt.rcParams.update({'figure.figsize': (10,10)})
result_M.plot().suptitle('Мультиплікатива модель')
# Out:
# Text(0.5, 0.98, 'Мультиплікатива модель')

# %%
df.value['2000']
# Out:
# date
# 2000-01-01    369.29
# 2000-02-01    369.54
# 2000-03-01    370.60
# 2000-04-01    371.82
# 2000-05-01    371.58
# 2000-06-01    371.70
# 2000-07-01    369.86
# 2000-08-01    368.13
# 2000-09-01    367.00
# 2000-10-01    367.03
# 2000-11-01    368.37
# 2000-12-01    369.67
# Name: value, dtype: float64

# %%
result_M.seasonal['2000']
# Out:
# date
# 2000-01-01    1.000135
# 2000-02-01    1.001929
# 2000-03-01    1.004054
# 2000-04-01    1.007302
# 2000-05-01    1.008530
# 2000-06-01    1.006555
# 2000-07-01    1.001988
# 2000-08-01    0.995917
# 2000-09-01    0.991096
# 2000-10-01    0.990812
# 2000-11-01    0.994200
# 2000-12-01    0.997482
# Name: seasonal, dtype: float64

# %%
result_M.trend['2000']
# Out:
# date
# 2000-01-01    368.840417
# 2000-02-01    368.908750
# 2000-03-01    369.051250
# 2000-04-01    369.211667
# 2000-05-01    369.349583
# 2000-06-01    369.483750
# 2000-07-01    369.603333
# 2000-08-01    369.739583
# 2000-09-01    369.897917
# 2000-10-01    370.038750
# 2000-11-01    370.197917
# 2000-12-01    370.355417
# Name: trend, dtype: float64

# %%
result_A = seasonal_decompose(df.value, model='additive', extrapolate_trend=12)

plt.rcParams.update({'figure.figsize': (10,10)})
result_A.plot().suptitle('Адитивна модель')
# Out:
# Text(0.5, 0.98, 'Адитивна модель')

# %%
result_A.seasonal['2000']
# Out:
# date
# 2000-01-01    0.059289
# 2000-02-01    0.688213
# 2000-03-01    1.435042
# 2000-04-01    2.579879
# 2000-05-01    3.010959
# 2000-06-01    2.308198
# 2000-07-01    0.687431
# 2000-08-01   -1.456150
# 2000-09-01   -3.152087
# 2000-10-01   -3.241776
# 2000-11-01   -2.041328
# 2000-12-01   -0.877669
# Name: seasonal, dtype: float64

# %%
result_M.seasonal['2000']
# Out:
# date
# 2000-01-01    1.000135
# 2000-02-01    1.001929
# 2000-03-01    1.004054
# 2000-04-01    1.007302
# 2000-05-01    1.008530
# 2000-06-01    1.006555
# 2000-07-01    1.001988
# 2000-08-01    0.995917
# 2000-09-01    0.991096
# 2000-10-01    0.990812
# 2000-11-01    0.994200
# 2000-12-01    0.997482
# Name: seasonal, dtype: float64

# %%
anomalies[anomalies]
# Out:
# date
# 1958-09-01    True
# 1958-10-01    True
# 1958-11-01    True
# 1959-10-01    True
# dtype: bool

# %%
df.loc['1958-09-01']=df.loc['1959-09-01']
df.loc['1958-10-01']=df.loc['1960-10-01']
df.loc['1958-11-01']=df.loc['1959-11-01']
df.loc['1959-10-01']=df.loc['1960-10-01']

# df.loc['1958-09-01']=df.loc['1961-09-01']
# df.loc['1958-10-01']=df.loc['1961-10-01']
# df.loc['1959-09-01']=df.loc['1961-09-01']
# df.loc['1959-10-01']=df.loc['1961-10-01']
# df.loc['1960-09-01']=df.loc['1961-09-01']
# df.loc['1960-10-01']=df.loc['1961-10-01']
# df.loc['2018-05-01']=df.loc['2017-05-01']
# df.loc['2018-06-01']=df.loc['2017-06-01']

# %%
outlier_detector = OutlierDetector(LocalOutlierFactor())
anomalies = outlier_detector.fit_detect(df)
# contamination=0.01
plot(df, anomaly=anomalies, ts_linewidth=2, anomaly_color='red', anomaly_alpha=0.3, curve_group='all');

# %%
df
# Out:
#              value
# date
# 1958-03-01  315.71
# 1958-04-01  317.45
# 1958-05-01  317.50
# 1958-06-01  317.10
# 1958-07-01  315.86
# ...            ...
# 2018-07-01  408.71
# 2018-08-01  406.99
# 2018-09-01  405.51
# 2018-10-01  406.00
# 2018-11-01  408.02
#
# [729 rows x 1 columns]

# %%
train=df['1958':'2010']
train
# Out:
#              value
# date
# 1958-03-01  315.71
# 1958-04-01  317.45
# 1958-05-01  317.50
# 1958-06-01  317.10
# 1958-07-01  315.86
# ...            ...
# 2010-08-01  388.35
# 2010-09-01  386.85
# 2010-10-01  387.24
# 2010-11-01  388.67
# 2010-12-01  389.79
#
# [634 rows x 1 columns]

# %%
test=df['2010':'2018']
test
# Out:
#              value
# date
# 2010-01-01  388.71
# 2010-02-01  390.20
# 2010-03-01  391.17
# 2010-04-01  392.46
# 2010-05-01  393.00
# ...            ...
# 2018-07-01  408.71
# 2018-08-01  406.99
# 2018-09-01  405.51
# 2018-10-01  406.00
# 2018-11-01  408.02
#
# [107 rows x 1 columns]

# %% [markdown]
# ## Модель Хольта-Вінтерса

# %%
fit1 = ExponentialSmoothing(train, seasonal_periods=12, trend='add', seasonal='mul').fit()

# %%
fit1.params
# Out:
# {'smoothing_level': 0.7180302016582719,
#  'smoothing_trend': 0.00922970478193125,
#  'smoothing_seasonal': 1.352061140431437e-17,
#  'damping_trend': nan,
#  'initial_level': 316.35298297886,
#  'initial_trend': 0.08501644128262255,
#  'initial_seasons': array([0.99817159, 1.00136768, 1.00253736, 1.00063626, 0.99610144,
#         0.9900265 , 0.98519307, 0.98491118, 0.98821944, 0.99148785,
#         0.99414471, 0.99601548]),
#  'use_boxcox': False,
#  'lamda': None,
#  'remove_bias': False}

# %%
fit1.fittedvalues
# Out:
# date
# 1958-03-01    315.859421
# 1958-04-01    316.847291
# 1958-05-01    317.738902
# 1958-06-01    317.051653
# 1958-07-01    315.735769
#                  ...
# 2010-08-01    388.087645
# 2010-09-01    386.533687
# 2010-10-01    386.805473
# 2010-11-01    388.576518
# 2010-12-01    390.088913
# Length: 634, dtype: float64

# %%
fit1.forecast(96)
# Out:
# 2011-01-01    391.077344
# 2011-02-01    391.971891
# 2011-03-01    392.979374
# 2011-04-01    394.397146
# 2011-05-01    395.017498
#                  ...
# 2018-08-01    403.805212
# 2018-09-01    401.990686
# 2018-10-01    402.032521
# 2018-11-01    403.540306
# 2018-12-01    405.032866
# Freq: MS, Length: 96, dtype: float64

# %%
ax = df.plot(figsize=(15,6), color='black', title="Прогноз методом Хольта Винтерса" )
fit1.fittedvalues.plot(ax=ax, style='--', color='red')
fit1.forecast(12).plot(ax=ax, style='--', color='green')
plt.show()

# %%
metrics(train, fit1.fittedvalues)
# Out:
# Тест на стаціонарність:
# 	T-статистика = -6.848
# 	P-значення = 0.000
# Критичне значення :
# 	1%: -3.4410277306083668 - Дані  стационарні з ймовірністю 99% відсотків
# 	5%: -2.8662510413264357 - Дані  стационарні з ймовірністю 95% відсотків
# 	10%: -2.569278890210853 - Дані  стационарні з ймовірністю 90% відсотків
# MAD: 0.2322
# MSE: 0.09
# MAPE: 0.0007
# MPE: 0.0
# Стандартна похибка: 0.3

# %%
metrics(test, fit1.forecast(len(test)))
# Out:
# Тест на стаціонарність:
# 	T-статистика = -0.363
# 	P-значення = 0.916
# Критичне значення :
# 	1%: -3.4942202045135513 - Дані не стационарні з ймовірністю 99% відсотків
# 	5%: -2.889485291005291 - Дані не стационарні з ймовірністю 95% відсотків
# 	10%: -2.5816762131519275 - Дані не стационарні з ймовірністю 90% відсотків
# MAD: 1.3736
# MSE: 2.2997
# MAPE: 0.0035
# MPE: -0.0015
# Стандартна похибка: 1.5165

# %%
plt.rcParams.update({'figure.figsize': (10,3)})
plot_acf(train.value, lags=24)
plot_pacf(train.value, lags=24)
plt.show()

# %% [markdown]
# ## ARIMA

# %%
model = auto_arima(train, 
                   seasonal=True, 
                   m=12, trace=True, 
                   suppress_warnings=True, 
                   error_action='ignore', 
                   stepwise=True)
model
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=428.664, Time=5.77 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=2037.464, Time=0.08 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=inf, Time=1.22 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=1355.973, Time=0.75 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=2041.397, Time=0.08 sec
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=inf, Time=4.01 sec
#  ARIMA(2,1,2)(1,0,0)[12] intercept   : AIC=630.156, Time=4.13 sec
#  ARIMA(2,1,2)(2,0,1)[12] intercept   : AIC=436.516, Time=10.91 sec
#  ARIMA(2,1,2)(1,0,2)[12] intercept   : AIC=451.069, Time=11.01 sec
#  ARIMA(2,1,2)(0,0,0)[12] intercept   : AIC=1207.577, Time=1.01 sec
#  ARIMA(2,1,2)(0,0,2)[12] intercept   : AIC=inf, Time=11.38 sec
#  ARIMA(2,1,2)(2,0,0)[12] intercept   : AIC=512.054, Time=12.85 sec
#  ARIMA(2,1,2)(2,0,2)[12] intercept   : AIC=393.718, Time=16.60 sec
#  ARIMA(1,1,2)(2,0,2)[12] intercept   : AIC=395.340, Time=15.20 sec
#  ARIMA(2,1,1)(2,0,2)[12] intercept   : AIC=391.003, Time=13.78 sec
#  ARIMA(2,1,1)(1,0,2)[12] intercept   : AIC=469.314, Time=10.66 sec
#  ARIMA(2,1,1)(2,0,1)[12] intercept   : AIC=493.103, Time=10.86 sec
#  ARIMA(2,1,1)(1,0,1)[12] intercept   : AIC=417.118, Time=3.87 sec
#  ARIMA(1,1,1)(2,0,2)[12] intercept   : AIC=373.291, Time=12.60 sec
#  ARIMA(1,1,1)(1,0,2)[12] intercept   : AIC=412.330, Time=9.93 sec
#  ARIMA(1,1,1)(2,0,1)[12] intercept   : AIC=399.441, Time=9.48 sec
#  ARIMA(1,1,1)(1,0,1)[12] intercept   : AIC=395.960, Time=3.75 sec
#  ARIMA(0,1,1)(2,0,2)[12] intercept   : AIC=379.903, Time=10.78 sec
#  ARIMA(1,1,0)(2,0,2)[12] intercept   : AIC=inf, Time=9.84 sec
#  ARIMA(0,1,0)(2,0,2)[12] intercept   : AIC=419.808, Time=9.11 sec
#  ARIMA(0,1,2)(2,0,2)[12] intercept   : AIC=inf, Time=14.72 sec
#  ARIMA(2,1,0)(2,0,2)[12] intercept   : AIC=inf, Time=11.17 sec
#  ARIMA(1,1,1)(2,0,2)[12]             : AIC=inf, Time=11.60 sec
#
# Best model:  ARIMA(1,1,1)(2,0,2)[12] intercept
# Total fit time: 237.615 seconds
# ARIMA(order=(1, 1, 1), scoring_args={}, seasonal_order=(2, 0, 2, 12),
#       suppress_warnings=True)

# %%
mod = sm.tsa.statespace.SARIMAX(train,
                                order=(1, 0, 1),
                                seasonal_order=(2, 0, 2, 12))

results = mod.fit(disp=False)

print(results.summary().tables[1])
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9970      0.001   1076.984      0.000       0.995       0.999
# ma.L1         -0.2870      0.027    -10.531      0.000      -0.340      -0.234
# ar.S.L12       0.0119      0.000     38.399      0.000       0.011       0.013
# ar.S.L24       0.9880      0.000   3125.093      0.000       0.987       0.989
# ma.S.L12       0.1483      0.017      8.799      0.000       0.115       0.181
# ma.S.L24      -0.8447      0.003   -322.946      0.000      -0.850      -0.840
# sigma2         0.0958      0.005     17.414      0.000       0.085       0.107
# ==============================================================================

# %%
results.plot_diagnostics(figsize=(15, 12))
plt.show()

# %%
predict=results.get_prediction()
predict.predicted_mean[:10]
# Out:
# 1958-03-01      0.000000
# 1958-04-01    315.675798
# 1958-05-01    316.876003
# 1958-06-01    317.189971
# 1958-07-01    317.018660
# 1958-08-01    316.215011
# 1958-09-01    315.450075
# 1958-10-01    314.643797
# 1958-11-01    314.479551
# 1958-12-01    315.021158
# Freq: MS, Name: predicted_mean, dtype: float64

# %%
predict=results.get_prediction(start='1958-03-01')
metrics(train['1958-03-01':], predict.predicted_mean)
# Out:
# Тест на стаціонарність:
# 	T-статистика = -7.261
# 	P-значення = 0.000
# Критичне значення :
# 	1%: -3.4410627157395908 - Дані  стационарні з ймовірністю 99% відсотків
# 	5%: -2.8662664495424255 - Дані  стационарні з ймовірністю 95% відсотків
# 	10%: -2.5692871001333266 - Дані  стационарні з ймовірністю 90% відсотків
# MAD: 0.759
# MSE: 157.33
# MAPE: 0.0023
# MPE: 0.0017
# Стандартна похибка: 12.5431

# %%
predict=results.get_prediction(start='2018', end='2048')

# %%
ax = df.plot(figsize=(15,6), color='black', title="Прогноз методом SARIMA" )
results.fittedvalues.plot(ax=ax, style='--', color='red')
predict.predicted_mean.plot(ax=ax, style='--', color='green')
plt.show()

# %%
predict=results.get_prediction(start='2010-01-01', end='2018-11-01')
metrics(test, predict.predicted_mean)
# Out:
# Тест на стаціонарність:
# 	T-статистика = 1.327
# 	P-значення = 0.997
# Критичне значення :
# 	1%: -3.4961490537199116 - Дані не стационарні з ймовірністю 99% відсотків
# 	5%: -2.8903209639580556 - Дані не стационарні з ймовірністю 95% відсотків
# 	10%: -2.5821223452518263 - Дані не стационарні з ймовірністю 90% відсотків
# MAD: 3.3568
# MSE: 18.5396
# MAPE: 0.0083
# MPE: 0.0082
# Стандартна похибка: 4.3058

# %% [markdown]
# Згідно метрик моделей для даної вибірки більш підходить модель Хольта-Винтерса

# %%
df
# Out:
#              value
# date
# 1958-03-01  315.71
# 1958-04-01  317.45
# 1958-05-01  317.50
# 1958-06-01  317.10
# 1958-07-01  315.86
# ...            ...
# 2018-07-01  408.71
# 2018-08-01  406.99
# 2018-09-01  405.51
# 2018-10-01  406.00
# 2018-11-01  408.02
#
# [729 rows x 1 columns]

# %% [markdown]
# ## Модель Хольта-Вінтерса для прогнозування даних

# %%
fit1 = ExponentialSmoothing(df, seasonal_periods=12, trend='add', seasonal='mul').fit()

# %%
fit1.params
# Out:
# {'smoothing_level': 0.6471952549952253,
#  'smoothing_trend': 0.011709518702250322,
#  'smoothing_seasonal': 0.05112939595578858,
#  'damping_trend': nan,
#  'initial_level': 316.7681931771948,
#  'initial_trend': 0.07969121728496593,
#  'initial_seasons': array([0.99690251, 1.00019972, 1.00152558, 0.9997804 , 0.99559028,
#         0.98966577, 0.98486125, 0.9843673 , 0.98772882, 0.99059281,
#         0.99313897, 0.99496235]),
#  'use_boxcox': False,
#  'lamda': None,
#  'remove_bias': False}

# %%
fit1.fittedvalues
# Out:
# date
# 1958-03-01    315.866452
# 1958-04-01    316.888091
# 1958-05-01    317.755190
# 1958-06-01    317.117435
# 1958-07-01    315.857488
#                  ...
# 2018-07-01    409.058105
# 2018-08-01    406.661943
# 2018-09-01    405.254450
# 2018-10-01    405.535971
# 2018-11-01    407.316478
# Length: 729, dtype: float64

# %%
predicted_30_years = fit1.forecast(360)
predicted_30_years
# Out:
# 2018-12-01    409.270877
# 2019-01-01    410.502954
# 2019-02-01    411.320434
# 2019-03-01    412.367219
# 2019-04-01    413.905211
#                  ...
# 2048-07-01    479.510759
# 2048-08-01    476.987388
# 2048-09-01    475.063830
# 2048-10-01    475.189877
# 2048-11-01    476.868571
# Freq: MS, Length: 360, dtype: float64

# %%
ax = df.plot(figsize=(15,6), color='black', title="Прогноз методом Хольта Винтерса" )
fit1.fittedvalues.plot(ax=ax, style='--', color='red')
fit1.forecast(360).plot(ax=ax, style='--', color='green')
plt.show()

# %%
predicted_30_years.to_csv('predicted_30_years.csv')
