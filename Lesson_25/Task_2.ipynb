# %% [markdown]
# # Завдання
# Розглянемо дві різні умовні акції 𝑋 та 𝑌. Для кожної з них за допомогою статистичних дослідженеь були розраховані відносні частоти очікуваних прибутків залежно від п'яти станів економічного середовища: значне піднесення (ЗС), незначне піднесення (НЗП), стагнація (С), незначний спад (НЗС), значний спад (ЗС). Ці дані занесені відповідно в останній рядок і останній стовпчик таблиці. Залежно від економічної середовища прогнозовані норми очікуваних прибутків у відсотках задані відповідно у першому рядку та першому стовпчику таблиці. У клітинках на перетині 𝑋 і 𝑌 проставлені ймовірногсті появи норм відсотків значень (x, y).

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Необхідно:
# 1) обчислити очікувану норму прибутку по кожній з акцій;
# 2) оцінити ступінь ризику обох акцій за допомогою середньоквадратичного відхилення;
# 3) проаналізувати наявність зв'язку між акціями X та Y за допомогою коефіцієнтів коваріації та кореляції.

# %% [markdown]
# # Розв'язок

# %% [markdown]
# 1) Очікувана норма прибутку акції визначається за відповідним умовним математичним очікуванням.
#
# $M(Y/x) = \sum^m_{j=1}y_jp(y_j,x)$
#
# $M(X/y) = \sum^n_{i=1}x_ip(x_i,y)$

# %% [markdown]
# $M(Y/x) = 20∙0,1 + 10∙0,3 + 2∙0,2 + (-2)∙0,3 + (-8)∙0,1=$

# %%
round(20*0.1 + 10*0.3 + 2*0.2 + (-2)*0.3 + (-8)*0.1, 3)
# Out:
# 4.0

# %% [markdown]
# $M(X/y) = 10∙0,1 + 5∙0,3 + 2∙0,2 + 1∙0,3 + (-5)∙0,1=$

# %%
round(10*0.1 + 5*0.3 + 2*0.2 + 1*0.3 + (-5)*0.1, 3)
# Out:
# 2.7

# %% [markdown]
# 2) Для середньоквадратичного відхилення спочатку визначимо умовну дисперсію для кожної акції:
# $D[Y/X=x] = M[(Y-M[Y])^2] = 0,1∙(20-4)^2+0,3∙(10-4)^2+0,2∙(2-4)^2+0,3∙(-2-4)^2+0,1∙(-8-4)^2=$

# %%
round(0.1*(20-4)**2 + 0.3*(10-4)**2 + 0.2*(2-4)**2 + 0.3*(-2-4)**2 + 0.1*(-8-4)**2, 3)
# Out:
# 62.4

# %% [markdown]
# $D[X/Y=y] = M[(X-M[X])^2] = 0,1∙(10-2,7)^2+0,3∙(5-2,7)^2+0,2∙(2-2,7)^2+0,3∙(1-2,7)^2+0,1∙(-5-2,7)^2=$

# %%
round(0.1*(10-2.7)**2 + 0.3*(5-2.7)**2 + 0.2*(2-2.7)**2 + 0.3*(1-2.7)**2 + 0.1*(-5-2.7)**2, 3)
# Out:
# 13.81

# %% [markdown]
# Середньоквадратичне відхилення відповідно:
# 1) $\sigma_y = \sqrt{D[Y/X=x]} = \sqrt{62.4} = $

# %%
round(62.4**0.5, 3)
# Out:
# 7.899

# %% [markdown]
# 2) $\sigma_x = \sqrt{D[X/Y=y]} = \sqrt{13.81} =$

# %%
round(13.81**0.5, 3)
# Out:
# 3.716

# %% [markdown]
# Оскільки $\sigma_x < \sigma_y$, то акція Х менш ризикова.

# %% [markdown]
# 3. Розрахуємо коефіцієнти коваріації та кореляції.
#
# $cov(X,Y) = M[XY] - M[X]M[Y]$

# %%
20*10*0.01 + 10*10*0.03 + 2*10*0.02 + (-2)*10*0.03 + (-8)*10*0.01 + 20*5*0.03 + 10*5*0.09 + 2*5*0.06 + (-2)*5*0.09 + (-8)*5*0.03 + 20*2*0.02 + 10*2*0.06 + 2*2*0.04 + (-2)*2*0.06 + (-8)*2*0.02 + 20*1*0.03 + 10*1*0.09 + 2*1*0.06 + (-2)*1*0.09 + (-8)*1*0.03 + 20*(-5)*0.01 + 10*(-5)*0.03 + 2*(-5)*0.02 + (-2)*(-5)*0.03 + (-8)*(-5)*0.01 - 2.7*4
# Out:
# 0.0

# %% [markdown]
# Оскільки коефіцієнт коваріації 𝑐𝑜𝑣(𝑋,𝑌)=0, то акції незалежні один від одного.

# %% [markdown]
# Коефіцієнт кореляції відповідно:
# $r_{xy} = \frac{cov(X,Y)}{\sigma_x ∙ \sigma_y} = \frac{0}{3.716∙7.899} = 0$.
#
# Тому величини некорельовані.
